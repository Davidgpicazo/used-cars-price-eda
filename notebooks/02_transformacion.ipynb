# %%
import pandas as pd

# %%
# Lectura del dataset
df_cars = pd.read_csv("../data/carlistings.csv")

# %% [markdown]
# # 2 Limpieza
#
# En este apartado se llevarán a cabo diversas tareas de limpieza y preparación del dataset, como estandarizar nombres de columnas, eliminar campos innecesarios y convertir valores textuales en datos numéricos útiles. Además, se corregirán inconsistencias, se separará la marca del modelo y se añadirá una nueva clasificación del vehículo para facilitar análisis posteriores.

# %% [markdown]
# ## 2.1 Modificación de columnas
#
# En este apartado se normalizarán los nombres de las columnas para mantener un formato uniforme y más manejable en Python, aplicando minúsculas y guiones bajos. Además, se eliminará la columna "listingid" por no aportar información útil y presentar saltos en su secuencia

# %%
df_cars.columns = df_cars.columns.str.lower() # Nombra a minúscula (ya disponen del guión bajo)
df_cars.drop("listingid", axis = 1, inplace=True) # Elimina la columna "listingid" porque no me aporta nada para tratar estos datos
df_cars.sample() # Visualiza el cambio
# Out:
#                         name   location  year  kilometers_driven fuel_type  \
# 199  Toyota Etios Liva GD SP  Hyderabad  2014             104000    Diesel
#
#     transmission owner_type     mileage   engine      power  seats  price
# 199       Manual      First  23.59 kmpl  1364 CC  67.06 bhp      5   4000

# %% [markdown]
# ## 2.2 Normalizar formatos y corregir incoherencias
#
# Aquí se retirarán las unidades y símbolos presentes en estas columnas para convertirlas en valores numéricos tipo int o float. Esto permitirá realizar cálculos fiables, obtener máximos y mínimos coherentes y facilitar cualquier análisis estadístico posterior.

# %% [markdown]
# ### 2.2.1 Búsqueda de incoherencias
#
# En este apartado se realizará una exploración inicial del dataset para detectar valores anómalos, formatos irregulares o datos que se salgan de los rangos esperados. Esta revisión preliminar permitirá identificar los principales problemas a corregir durante las fases posteriores de limpieza.

# %%
df_cars.duplicated().sum() 

    # Revisa que no haya duplicados que se deban tratar
# Out:
# np.int64(0)

# %%
df_cars["fuel_type"].unique() 

    # Revisa para esta variable cualitativa los distintos valores para observar que no haya nada raro
# Out:
# array(['Diesel', 'Petrol'], dtype=object)

# %%
df_cars["transmission"].unique() 

    # Revisa para esta variable cualitativa los distintos valores para observar que no haya nada raro
# Out:
# array(['Manual', 'Automatic'], dtype=object)

# %%
df_cars["owner_type"].unique() 
    
    # Revisa para esta variable cualitativa los distintos valores para observar que no haya nada raro
# Out:
# array(['First', 'Second', 'Fourth & Above', 'Third'], dtype=object)

# %%
df_cars["mileage"].unique() 

    # Revisa para esta variable cualitativa los distintos valores para observar que no haya nada raro
        # Se muestran dos tipos de unidades: kmpl y km/kg. 
            # kmpl: Suele referirse a kilómetros por litro, común en coches diesel o gasolina
            # km/kg: Suele referirse a kilómetros por kilo, común en coches de gas (GNC, GLP...)
        # Se muestran coches con 0 --> valor llamativo
# Out:
# array(['19.67 kmpl', '13 km/kg', '20.77 kmpl', '15.2 kmpl', '23.08 kmpl',
#        '11.36 kmpl', '20.54 kmpl', '22.3 kmpl', '21.56 kmpl', '16.8 kmpl',
#        '25.2 kmpl', '12.7 kmpl', '0.0 kmpl', '13.5 kmpl', '25.8 kmpl',
#        '28.4 kmpl', '20.45 kmpl', '14.84 kmpl', '22.69 kmpl',
#        '23.65 kmpl', '13.53 kmpl', '18.5 kmpl', '14.4 kmpl',
#        '16.48 km/kg', '20.92 kmpl', '17.5 kmpl', '12.8 kmpl',
#        '19.01 kmpl', '14.53 kmpl', '11.18 kmpl', '12.4 kmpl',
#        '16.09 kmpl', '14.0 kmpl', '24.3 kmpl', '18.15 kmpl', '11.74 kmpl',
#        '22.07 kmpl', '19.7 kmpl', '25.4 kmpl', '25.32 kmpl', '14.62 kmpl',
#        '14.28 kmpl', '14.9 kmpl', '11.25 kmpl', '24.4 kmpl', '16.55 kmpl',
#        '17.11 kmpl', '22.9 kmpl', '17.8 kmpl', '18.9 kmpl', '15.04 kmpl',
#        '25.17 kmpl', '20.36 kmpl', '9.49 km/kg', '18.2 kmpl',
#        '13.68 kmpl', '20.0 kmpl', '15.8 kmpl', '25.0 kmpl', '16.4 kmpl',
#        '24.52 kmpl', '22.1 kmpl', '8.5 kmpl', '15.1 kmpl', '16.95 kmpl',
#        '19.64 kmpl', '16.5 kmpl', '18.53 kmpl', '17.57 kmpl', '18.0 kmpl',
#        '23.2 kmpl', '16.73 kmpl', '13.0 kmpl', '17.68 kmpl', '22.7 kmpl',
#        '16.2 kmpl', '15.26 kmpl', '23.0 kmpl', '19.83 kmpl', '14.94 kmpl',
#        '17.0 kmpl', '17.71 kmpl', '14.74 kmpl', '16.0 kmpl', '22.32 kmpl',
#        '12.99 kmpl', '23.3 kmpl', '19.15 kmpl', '10.8 kmpl', '15.0 kmpl',
#        '22.0 kmpl', '21.9 kmpl', '12.05 kmpl', '11.7 kmpl', '21.21 kmpl',
#        '20.73 kmpl', '21.1 kmpl', '24.07 kmpl', '19.0 kmpl', '20.58 kmpl',
#        '19.27 kmpl', '11.5 kmpl', '18.6 kmpl', '21.14 kmpl', '11.05 kmpl',
#        '21.76 kmpl', '7.81 kmpl', '21.66 kmpl', '17.2 kmpl', '20.63 kmpl',
#        '19.4 kmpl', '14.8 kmpl', '26.0 kmpl', '20.4 kmpl', '21.5 kmpl',
#        '15.3 kmpl', '17.9 kmpl', '16.6 kmpl', '22.54 kmpl', '25.44 kmpl',
#        '13.7 kmpl', '22.48 kmpl', '12.9 kmpl', '19.98 kmpl', '21.4 kmpl',
#        '19.81 kmpl', '15.4 kmpl', '25.47 kmpl', '19.87 kmpl',
#        '17.45 kmpl', '14.7 kmpl', '15.64 kmpl', '15.73 kmpl',
#        '23.59 kmpl', '16.1 kmpl', '27.4 kmpl', '20.46 kmpl', '15.29 kmpl',
#        '20.51 kmpl', '11.8 kmpl', '14.3 kmpl', '14.67 kmpl', '17.19 kmpl',
#        '21.03 kmpl', '22.5 kmpl', '16.82 kmpl', '11.72 kmpl', '17.4 kmpl',
#        '17.05 kmpl', '24.0 kmpl', '28.09 kmpl', '20.5 kmpl', '13.1 kmpl',
#        '19.91 kmpl', '18.7 kmpl', '16.38 kmpl', '11.57 kmpl', '17.3 kmpl',
#        '22.95 kmpl', '18.88 kmpl', '23.4 kmpl', '22.74 kmpl',
#        '12.07 kmpl', '17.1 kmpl', '18.48 kmpl', '16.47 kmpl'],
#       dtype=object)

# %%
df_cars["engine"].unique() 

    # Revisa para esta variable cualitativa los distintos valores para observar que no haya nada raro
        # Unidades en "CC" que se refiere a la cilindrada --> Estas unidades no son importantes para el análisis, se deberán quitar
# Out:
# array(['1582 CC', '1199 CC', '1248 CC', '1968 CC', '1461 CC', '2755 CC',
#        '1598 CC', '1462 CC', '1497 CC', '2179 CC', '2477 CC', '1498 CC',
#        '2143 CC', '1995 CC', '1984 CC', '1197 CC', '998 CC', '2494 CC',
#        '1798 CC', '2696 CC', '2698 CC', '1061 CC', '1198 CC', '2987 CC',
#        '796 CC', '624 CC', '1999 CC', '1991 CC', '2694 CC', '1120 CC',
#        '2498 CC', '799 CC', '2393 CC', '1399 CC', '1796 CC', '2148 CC',
#        '1396 CC', '1950 CC', '4806 CC', '1998 CC', '1193 CC', '2982 CC',
#        '1493 CC', '2967 CC', '2993 CC', '1196 CC', '1799 CC', '2497 CC',
#        '2354 CC', '1373 CC', '2996 CC', '1591 CC', '2894 CC', '5461 CC',
#        '814 CC', '1595 CC', '936 CC', '1086 CC', '1997 CC', nan,
#        '1896 CC', '1390 CC', '1364 CC', '2199 CC', '993 CC', '999 CC',
#        '1405 CC'], dtype=object)

# %%
df_cars["power"].unique() 

    # Revisa para esta variable cualitativa los distintos valores para observar que no haya nada raro
        # Unidades en bhp (brake Horsepower) que se refiere a los caballos del coche --> Estas unidades no son importantes para el análisis, se deberán quitar
# Out:
# array(['126.2 bhp', '88.7 bhp', '88.76 bhp', '140.8 bhp', '63.1 bhp',
#        '171.5 bhp', '103.6 bhp', '74 bhp', '103.25 bhp', '116.3 bhp',
#        '187.7 bhp', '115 bhp', '175.56 bhp', '98.6 bhp', '83.8 bhp',
#        '167.62 bhp', '190 bhp', '88.5 bhp', '177.01 bhp', '80 bhp',
#        '67.1 bhp', '102 bhp', '108.45 bhp', '138.1 bhp', '184 bhp',
#        '179.5 bhp', '103.5 bhp', '64 bhp', '82 bhp', '254.8 bhp',
#        '73.9 bhp', '46.3 bhp', '37.5 bhp', '77 bhp', '82.9 bhp',
#        '149.92 bhp', '138.03 bhp', '112.2 bhp', '163.7 bhp', '71 bhp',
#        '105 bhp', '174.33 bhp', '75 bhp', '103.2 bhp', '53.3 bhp',
#        '78.9 bhp', '147.6 bhp', '147.8 bhp', '68 bhp', '186 bhp',
#        '170 bhp', '69 bhp', '140 bhp', '78 bhp', '194 bhp', '500 bhp',
#        '108.5 bhp', '86.8 bhp', '187.74 bhp', '132 bhp', '86.7 bhp',
#        '73.94 bhp', '117.3 bhp', '218 bhp', '168.5 bhp', '89.84 bhp',
#        '110 bhp', '90 bhp', '82.85 bhp', '67 bhp', '241.4 bhp', '35 bhp',
#        '270.9 bhp', '126.32 bhp', '73 bhp', '130 bhp', '100.6 bhp',
#        '150 bhp', '75.94 bhp', '215 bhp', '107.3 bhp', '37.48 bhp',
#        '120 bhp', '178 bhp', '152 bhp', '91.1 bhp', '85.80 bhp',
#        '362.07 bhp', '121.3 bhp', '143 bhp', '81.80 bhp', '171 bhp',
#        '76.8 bhp', '103.52 bhp', '444 bhp', '362.9 bhp', '55.2 bhp',
#        '67.06 bhp', '120.7 bhp', '258 bhp', '81.86 bhp', '112 bhp',
#        '88.73 bhp', '57.6 bhp', '157.75 bhp', '102.5 bhp', '201.1 bhp',
#        '83.1 bhp', '68.05 bhp', '88.50 bhp', nan, '106 bhp', '100 bhp',
#        '81.83 bhp', '85 bhp', '64.1 bhp', '177.5 bhp', '246.7 bhp',
#        '177.46 bhp', '65 bhp', '67.04 bhp', '189.08 bhp', '99 bhp',
#        '53.5 bhp', '194.3 bhp', '70 bhp', '183 bhp', '254.79 bhp',
#        '66.1 bhp', '76 bhp', '60 bhp', '123.24 bhp', '47.3 bhp',
#        '118 bhp', '88.8 bhp', '177 bhp', '136 bhp'], dtype=object)

# %%
df_cars["seats"].unique() 

# Revisa el número de asientos ya que se ha identificado un valor de "0", y se desea saber si existen más valores menores de 2
    # Se tendrá que revisar los coches con "0" asientos, si no son muchos, se podrían buscar en internet y completarlos
        # También se podría revisar si existen mismos modelos con otro número de asientos
# Out:
# array([5, 7, 8, 4, 6, 2, 0])

# %% [markdown]
# ### 2.2.2 Corregir incoherencia en "mileage"
#
# En este apartado se revisarán los valores de "mileage" para detectar datos que no encajen con el rango esperado o presenten formatos incorrectos. Una vez identificadas las incoherencias, se corregirán o sustituirán para garantizar que el kilometraje represente valores reales y consistentes.

# %%
df_cars[df_cars["mileage"].str.contains("km/kg")] 

    # Visualiza las columnas con "km/kg" en "mileage"
        # Observamos que el combustible no es gas
        # Como son únicamente 3 coches, los vemos en internet y comprobamos que no suelen ser de gas
            # De este modo corroboramos que es una equivocación al añadir las unidades y que podemos considerarlo como "kmpl"
# Out:
#                       name    location  year  kilometers_driven fuel_type  \
# 1             Honda Jazz V   Islamabad  2011              46000    Petrol
# 24  Nissan Micra Diesel XV  Abbottabad  2012              54000    Diesel
# 56   Nissan X-Trail SLX AT  Abbottabad  2010             121812    Diesel
#
#    transmission owner_type      mileage   engine      power  seats  price
# 1        Manual      First     13 km/kg  1199 CC   88.7 bhp      5   6000
# 24       Manual      First  16.48 km/kg  1461 CC   63.1 bhp      5   5666
# 56    Automatic      First   9.49 km/kg  1995 CC  147.6 bhp      5  10333

# %%
df_cars["mileage"] = df_cars["mileage"].str.replace("km/kg", "kmpl") 

    # Modifica las unidades a "kmpl" para unificar unidades (aunque luego lo eliminemos)

# %% [markdown]
# ### 2.2.3 Revisar y tratar valores nulos/incoherentes de "engine" y "power"
#
# Aquí se analizarán ambas columnas para identificar valores faltantes o poco plausibles que puedan distorsionar el análisis. Se aplicarán estrategias como imputación, corrección manual o eliminación de registros en caso de ser necesario para asegurar la integridad del dataset.

# %%
df_cars.isna().sum() 

    # Revisa qué columnas tienen valores nulos
        # Vemos que "engine" y "power" tienen 2 valores nulos cada uno
# Out:
# name                 0
# location             0
# year                 0
# kilometers_driven    0
# fuel_type            0
# transmission         0
# owner_type           0
# mileage              0
# engine               2
# power                2
# seats                0
# price                0
# dtype: int64

# %%
df_cars[(df_cars["engine"].isnull()) | (df_cars["power"].isnull())] 

    # Visualiza las filas con valores nulos
        # No quiero eliminar estas filas si no es necesario
        # Reviso primero si hay modelos iguales --> Si no, añadiré la media
# Out:
#                    name   location  year  kilometers_driven fuel_type  \
# 186  Honda City 1.5 GXI    Chitral  2007              60006    Petrol
# 200         Honda Civic  Faislabad  2010              42001    Petrol
#
#     transmission owner_type    mileage engine power  seats  price
# 186       Manual      First   0.0 kmpl    NaN   NaN      0   3933
# 200       Manual      First  16.1 kmpl    NaN   NaN      0   2813

# %%
df_cars[df_cars["name"].str.contains("Honda City")] 

    # Revisa si todos los Honda City tienen CC similar
        # Todos son muy similares, y los de "1.5" tienen 1497 CC. Que coincide con la moda, añadiré este valor
# Out:
#                              name    location  year  kilometers_driven  \
# 9     Honda City 1.5 V AT Sunroof   Faislabad  2012              60000
# 23   Honda City Corporate Edition      Quetta  2012              51920
# 64              Honda City ZX CVT      Quetta  2007              63000
# 81            Honda City i VTEC E   Hyderabad  2009              52000
# 152           Honda City i DTEC V      Multan  2015              42831
# 186            Honda City 1.5 GXI     Chitral  2007              60006
# 228           Honda City i-VTEC V   Faislabad  2011              32572
# 236           Honda City i VTEC V      Multan  2016              33915
# 270           Honda City 1.5 S MT  Rawalpindi  2011              55000
# 274           Honda City 1.5 V AT  Rawalpindi  2009              78442
# 278          Honda City i VTEC VX     Chitral  2014              49000
# 292      Honda City i-VTEC CVT ZX      Quetta  2017              15000
#
#     fuel_type transmission owner_type    mileage   engine      power  seats  \
# 9      Petrol    Automatic      First  16.8 kmpl  1497 CC  116.3 bhp      5
# 23     Petrol       Manual      First  16.8 kmpl  1497 CC  116.3 bhp      5
# 64     Petrol    Automatic     Second  16.4 kmpl  1497 CC     78 bhp      5
# 81     Petrol       Manual      First  17.8 kmpl  1497 CC  117.3 bhp      5
# 152    Diesel       Manual      First  26.0 kmpl  1498 CC   98.6 bhp      5
# 186    Petrol       Manual      First   0.0 kmpl      NaN        NaN      0
# 228    Petrol       Manual      First  17.4 kmpl  1497 CC  117.3 bhp      5
# 236    Petrol       Manual      First  17.8 kmpl  1497 CC  117.3 bhp      5
# 270    Petrol       Manual      First  17.0 kmpl  1497 CC    118 bhp      5
# 274    Petrol    Automatic      First  16.8 kmpl  1497 CC    118 bhp      5
# 278    Petrol       Manual      First  17.4 kmpl  1497 CC  117.3 bhp      5
# 292    Petrol    Automatic      First  18.0 kmpl  1497 CC  117.3 bhp      5
#
#      price
# 9     5986
# 23    5666
# 64    2466
# 81    4333
# 152   9480
# 186   3933
# 228   5160
# 236  10786
# 270   5613
# 274   4760
# 278   9200
# 292  16920

# %%
df_cars[df_cars["name"].str.contains("Honda City")].agg({"mileage": "mode", "power": "mode", "engine": "mode", "seats": "mode"})
    
    # Muestra la moda de las columnas ordenadas
        # Estos datos los añadiré al Honda City con valores nulos/incoherentes
# Out:
#      mileage      power   engine  seats
# 0  16.8 kmpl  117.3 bhp  1497 CC      5

# %%
df_cars.loc[186, "mileage"] = "16.8 kmpl"
df_cars.loc[186, "power"] = "117.3 bhp"
df_cars.loc[186, "engine"] = "1497 CC"
df_cars.loc[186, "seats"] = 5

    # Cambia los valores del "Honda City", que corresponde con el número 186 del índice

# %%
df_cars[df_cars["name"].str.contains("Honda Civic")] 

    # Muestra todos los Honda Civic
        # Revisamos si hay datos que comparar para poder extraer una conclusión de qué valores añadir
        # Al no tener, sacaré la moda para no influir en exceso en el análisis posterior
            # Es una única fila y el resto de datos me conviene mantenerlos
# Out:
#                                name    location  year  kilometers_driven  \
# 19                      Honda Civic    Peshawar  2015              55392
# 40                      Honda Civic      Lahore  2017              22033
# 47                      Honda Civic  Rawalpindi  2012              75800
# 51                      Honda Civic   Hyderabad  2013              65650
# 62                      Honda Civic   Islamabad  2016             178000
# 89                      Honda Civic   Hyderabad  2014              58000
# 93                      Honda Civic    Peshawar  2016              62000
# 103                     Honda Civic   Hyderabad  2012              65000
# 109  Honda Civic 2006-2010 1.8 V MT   Hyderabad  2010              71088
# 123                     Honda Civic      Multan  2017              44285
# 132  Honda Civic 2006-2010 1.8 V MT   Hyderabad  2012              88578
# 200                     Honda Civic   Faislabad  2010              42001
# 215                     Honda Civic  Abbottabad  2013             107000
# 221                     Honda Civic  Rawalpindi  2007             200000
# 224                     Honda Civic  Abbottabad  2016              64000
# 239                     Honda Civic   Islamabad  2016              34000
# 248                     Honda Civic      Lahore  2017              27872
# 279                     Honda Civic     Karachi  2018              45000
# 291                     Honda Civic  Abbottabad  2011              70000
# 293                     Honda Civic      Lahore  2013              59138
#
#     fuel_type transmission owner_type     mileage   engine      power  seats  \
# 19     Diesel       Manual     Second  23.65 kmpl  1248 CC   88.5 bhp      5
# 40     Diesel       Manual      First  25.32 kmpl  1198 CC     77 bhp      6
# 47     Diesel       Manual     Second  16.55 kmpl  2498 CC    105 bhp      6
# 51     Diesel       Manual      First   28.4 kmpl  1248 CC     74 bhp      5
# 62     Diesel       Manual      First   25.0 kmpl  1396 CC     69 bhp      5
# 89     Diesel       Manual      First   15.1 kmpl  2179 CC    140 bhp      7
# 93     Petrol       Manual      First   18.9 kmpl   998 CC   67.1 bhp      5
# 103    Diesel       Manual     Second   16.0 kmpl  2179 CC    140 bhp      7
# 109    Petrol       Manual      First   13.5 kmpl  1799 CC    130 bhp      5
# 123    Petrol       Manual      First  20.73 kmpl  1373 CC   91.1 bhp      5
# 132    Petrol       Manual      First   13.5 kmpl  1799 CC    130 bhp      5
# 200    Petrol       Manual      First   16.1 kmpl      NaN        NaN      0
# 215    Diesel       Manual      First  21.03 kmpl  1461 CC     65 bhp      5
# 221    Diesel       Manual     Second   17.2 kmpl  1396 CC   53.5 bhp      5
# 224    Diesel       Manual      First   22.9 kmpl  1248 CC     74 bhp      5
# 239    Diesel       Manual      First  28.09 kmpl  1248 CC   88.5 bhp      5
# 248    Petrol       Manual     Second   20.4 kmpl  1197 CC  81.80 bhp      5
# 279    Diesel       Manual      First  22.95 kmpl  1248 CC     74 bhp      5
# 291    Petrol       Manual      First  20.92 kmpl   998 CC   67.1 bhp      5
# 293    Diesel       Manual      First   17.0 kmpl  1405 CC     70 bhp      5
#
#      price
# 19   11000
# 40    7440
# 47    7333
# 51    5133
# 62    3333
# 89   10800
# 93    5933
# 103   7666
# 109   4466
# 123   9960
# 132   5266
# 200   2813
# 215   4933
# 221   1133
# 224   9066
# 239  11266
# 248   7933
# 279   7000
# 291   2800
# 293   3440

# %%
df_cars[df_cars["name"].str.contains("Honda Civic")].agg({"power": "mode", "engine": "mode", "seats": "mode"})

    # Muestra la moda de las columnas de interés
        # Estos datos los añadiré al Honda Civic con valores nulos/incoherentes
# Out:
#     power   engine  seats
# 0  74 bhp  1248 CC      5

# %%
df_cars.loc[200, "power"] = "74 bhp"
df_cars.loc[200, "engine"] = "1248 CC"
df_cars.loc[200, "seats"] = 5

    # Cambia los valores del "Honda Civic", que corresponde con el número 186 del índice

# %% [markdown]
# ### 2.2.4 Quitar unidades y convertir en float/int los valores de "mileage", "engine" y "power"
#
# En este punto se eliminarán las unidades (como cc, kmpl o bhp) que acompañan a los valores originales y se transformarán en datos numéricos. Esta conversión permitirá realizar cálculos, comparaciones y visualizaciones precisas en el análisis posterior.

# %%
df_cars["mileage"] = df_cars["mileage"].str.extract(r"(\d+\.?\d*)").astype(float)
df_cars["engine"] = df_cars["engine"].str.extract(r"(\d+)").astype(int)
df_cars["power"] = df_cars["power"].str.extract(r"(\d+\.?\d*)").astype(float)

    # Elimina las unidades de "mileage", "engine" y "power"

# %%
df_cars.sample() 

    # Visualiza para comprobar que se han eliminado las unidades
# Out:
#                 name    location  year  kilometers_driven fuel_type  \
# 124  Subaru Forester  Rawalpindi  2016              54000    Diesel
#
#     transmission owner_type  mileage  engine  power  seats  price
# 124    Automatic      First     16.0    2179  140.0      7  17666

# %% [markdown]
# ### 2.2.5 Revisar y solucionar incoherencias no detectadas
#
# Finalmente, se realizará una revisión exhaustiva del dataset para identificar posibles errores que no hayan aparecido en los pasos anteriores. Se evaluarán patrones, outliers y combinaciones anómalas para asegurar que no queden inconsistencias ocultas que afecten al análisis final.

# %%
df_cars.info() 

    # Comprueba que se han cambiado los valores a float/int
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 296 entries, 0 to 295
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               296 non-null    object
#  1   location           296 non-null    object
#  2   year               296 non-null    int64
#  3   kilometers_driven  296 non-null    int64
#  4   fuel_type          296 non-null    object
#  5   transmission       296 non-null    object
#  6   owner_type         296 non-null    object
#  7   mileage            296 non-null    float64
#  8   engine             296 non-null    int64
#  9   power              296 non-null    float64
#  10  seats              296 non-null    int64
#  11  price              296 non-null    int64
# dtypes: float64(2), int64(5), object(5)
# memory usage: 27.9+ KB

# %%
df_cars.describe() 

    # Revisamos de nuevo que no haya outliers incoherentes
        # Se observa que el mínimo en "mileage" sigue siendo "0"
        # Se observa que el mínimo en "seats" sigue siendo "0" 
        # Revisaremos estos datos e intentaremos solucionarlo de la mejor manera posible
# Out:
#               year  kilometers_driven     mileage       engine       power  \
# count   296.000000         296.000000  296.000000   296.000000  296.000000
# mean   2013.540541       57791.131757   18.212399  1641.679054  115.548953
# std       2.971910       35160.124277    4.488974   605.490334   58.643606
# min    2002.000000        1000.000000    0.000000   624.000000   35.000000
# 25%    2012.000000       34153.000000   15.100000  1199.000000   76.950000
# 50%    2014.000000       53000.000000   18.500000  1497.000000  100.300000
# 75%    2016.000000       70000.500000   21.110000  1992.000000  140.000000
# max    2019.000000      262000.000000   28.400000  5461.000000  500.000000
#
#             seats         price
# count  296.000000    296.000000
# mean     5.239865  13137.266892
# std      0.835585  14238.860963
# min      0.000000    733.000000
# 25%      5.000000   4666.000000
# 50%      5.000000   7939.500000
# 75%      5.000000  14859.750000
# max      8.000000  93813.000000

# %%
df_cars[(df_cars["mileage"] == 0) | (df_cars["seats"] == 0)] 

    # Con estos datos se procede a:
        # Comparar con otros modelos
        # Si misma cilindrada, mismo consumo --> si no, sacar modas de "mileage" 
        # Mismo modelo de coche, mismos asientos
# Out:
#                                          name  location  year  \
# 12             Land Rover Freelander 2 TD4 SE   Karachi  2012
# 65   Mercedes-Benz C-Class Progressive C 220d    Lahore  2019
# 220                          Ford Figo Diesel  Peshawar  2015
#
#      kilometers_driven fuel_type transmission owner_type  mileage  engine  \
# 12               85000    Diesel    Automatic     Second      0.0    2179
# 65               15369    Diesel    Automatic      First      0.0    1950
# 220              70436    Diesel       Manual      First      0.0    1498
#
#      power  seats  price
# 12   115.0      5  23333
# 65   194.0      5  47560
# 220   99.0      0   4800

# %%
df_cars[df_cars["name"].str.contains("Land Rover")] 

    # Muestra los coches de la marca "Land Rover" 
        # Vemos que tiene misma cilindrada que el resto de "Land Rover" por lo que consideraremos mismo consumo aunque sea distinto modelo
# Out:
#                                     name   location  year  kilometers_driven  \
# 11      Land Rover Range Rover 2.2L Pure  Hyderabad  2014              72000
# 12        Land Rover Freelander 2 TD4 SE    Karachi  2012              85000
# 183  Land Rover Range Rover 2.2L Dynamic     Lahore  2018              36091
#
#     fuel_type transmission owner_type  mileage  engine  power  seats  price
# 11     Diesel    Automatic      First     12.7    2179  187.7      5  36000
# 12     Diesel    Automatic     Second      0.0    2179  115.0      5  23333
# 183    Diesel    Automatic      First     12.7    2179  187.7      5  74346

# %%
df_cars.loc[12, "mileage"] = 12.7

    # Cambia el valor de 0 a 12.7

# %%
df_cars[df_cars["name"].str.contains("Mercedes-Benz")] 

    # Muestra los coches de la marca "Mercedes-Benz" 
        # Hay valores muy dispares, usaremos la moda
# Out:
#                                                   name   location  year  \
# 17    Mercedes-Benz New C-Class C 220 CDI BE Avantgare   Peshawar  2014
# 36                    Mercedes-Benz M-Class ML 350 CDI    Karachi  2013
# 60      Mercedes-Benz New C-Class C 200 CGI Avantgarde  Hyderabad  2015
# 61           Mercedes-Benz New C-Class 200 CDI Classic    Karachi  2011
# 65            Mercedes-Benz C-Class Progressive C 220d     Lahore  2019
# 115                     Mercedes-Benz B Class B200 CDI    Karachi  2014
# 120                 Mercedes-Benz New C-Class 200 K AT  Faislabad  2009
# 127                           Mercedes-Benz SLC 43 AMG  Faislabad  2017
# 133     Mercedes-Benz New C-Class C 220 CDI Avantgarde     Multan  2014
# 144              Mercedes-Benz S Class 2005 2013 S 500  Faislabad  2010
# 151                         Mercedes-Benz B Class B180  Hyderabad  2013
# 161          Mercedes-Benz New C-Class C 220 CDI Style     Lahore  2017
# 164                              Mercedes-Benz GLC 220   Peshawar  2016
# 178          Mercedes-Benz E-Class E250 CDI Avantgrade   Peshawar  2014
# 201                         Mercedes-Benz B Class B180     Multan  2014
# 207          Mercedes-Benz New C-Class C250 Avantgarde  Faislabad  2010
# 216  Mercedes-Benz New C-Class C 220d Avantgarde Ed...     Lahore  2018
# 230  Mercedes-Benz New C-Class C 220d Avantgarde Ed...     Multan  2015
# 253                             Mercedes-Benz GLE 350d     Lahore  2017
# 254        Mercedes-Benz New C-Class C 220 CDI CLASSIC   Peshawar  2014
# 285     Mercedes-Benz New C-Class C 220 CDI Avantgarde     Multan  2015
# 295              Mercedes-Benz GLA Class 200 CDI SPORT  Hyderabad  2015
#
#      kilometers_driven fuel_type transmission owner_type  mileage  engine  \
# 17               78500    Diesel    Automatic      First    14.84    2143
# 36               85000    Diesel    Automatic      First    11.74    2987
# 60               58000    Petrol    Automatic      First    11.74    1796
# 61               65000    Diesel       Manual     Second    15.80    2148
# 65               15369    Diesel    Automatic      First     0.00    1950
# 115              53753    Diesel    Automatic     Second    15.00    2143
# 120              28352    Petrol    Automatic      First    11.70    1796
# 127              13372    Petrol    Automatic      First    19.00    2996
# 133              44965    Diesel    Automatic      First    19.27    2143
# 144              35277    Petrol    Automatic      First     7.81    5461
# 151              29000    Petrol    Automatic      First    14.80    1595
# 161              23550    Diesel    Automatic      First    19.27    2143
# 164              44414    Diesel    Automatic      First    17.90    2143
# 178              37382    Diesel    Automatic      First    13.00    2143
# 201              37245    Petrol    Automatic      First    14.80    1595
# 207              30500    Petrol    Automatic      First    11.74    1796
# 216              29161    Diesel    Automatic      First    19.27    2143
# 230              55980    Diesel    Automatic      First    19.27    2143
# 253              29819    Diesel    Automatic      First    11.57    2987
# 254              57000    Diesel       Manual     Second    15.80    2148
# 285              77771    Diesel    Automatic      First    19.27    2143
# 295              48000    Diesel    Automatic      First    17.90    2143
#
#       power  seats  price
# 17   167.62      5  37333
# 36   254.80      5  37333
# 60   186.00      5  35600
# 61   170.00      5  13333
# 65   194.00      5  47560
# 115  107.30      5  22333
# 120  178.00      5  12466
# 127  362.07      2  72000
# 133  170.00      5  23933
# 144  362.90      5  40000
# 151  120.70      5  15000
# 161  167.62      5  44879
# 164  170.00      5  56666
# 178  201.10      5  42666
# 201  120.70      5  15946
# 207  186.00      5  14000
# 216  167.62      5  52546
# 230  167.62      5  24160
# 253  254.79      5  81720
# 254  170.00      5  24000
# 285  170.00      5  24853
# 295  136.00      5  27013

# %%
df_cars[df_cars["name"].str.contains("Mercedes-Benz")].agg({"mileage" : "mode", "power": "mode", "engine": "mode", "seats": "mode"})

    # Muestra la moda para los "Mercedes-Benz" en las columnas necesarias
# Out:
#    mileage  power  engine  seats
# 0    19.27  170.0    2143      5

# %%
df_cars.loc[65, "mileage"] = 19.27 

    # Modifica el "0" por la moda obtenida

# %%
df_cars[df_cars["name"].str.contains("Ford Figo")] 

    # Muestra la tabla con todos los coche "Ford Figo" con el fin de poder comparar
        # No encontramos un modelo similar
            # Buscamos en internet el consumo aproximado que puede tener un Ford Figo Diesel (1.5 TDCi del 2015)
            #    Aproximadamente unos 24 kmpl
# Out:
#                           name    location  year  kilometers_driven fuel_type  \
# 59   Ford Figo Diesel Titanium    Peshawar  2010              72000    Diesel
# 79        Ford Figo Diesel ZXI  Abbottabad  2012              70337    Diesel
# 159  Ford Figo Diesel Titanium  Rawalpindi  2010              66123    Diesel
# 184       Ford Figo Diesel ZXI   Islamabad  2010             120000    Diesel
# 220           Ford Figo Diesel    Peshawar  2015              70436    Diesel
# 225       Ford Figo Diesel EXI   Faislabad  2012              41284    Diesel
#
#     transmission owner_type  mileage  engine  power  seats  price
# 59        Manual      First     20.0    1399  68.00      5   3666
# 79        Manual      First     20.0    1399  68.00      5   3733
# 159       Manual     Second     20.0    1399  68.00      5   2800
# 184       Manual      First     20.0    1399  68.00      5   3466
# 220       Manual      First      0.0    1498  99.00      0   4800
# 225       Manual      First     20.0    1399  68.05      5   3333

# %%
df_cars.loc[220, "mileage"] = 24 # Modifica el valor de "mileage"
df_cars.loc[220, "seats"] = 5 # Modifica el valor de "seats"

# %%
df_cars.describe() 

    # Comprueba que haya datos estadísticos coherentes
        # Ya tenemos datos cocherentes, podemos ultimar detalles y comenzar con el análisis
# Out:
#               year  kilometers_driven     mileage       engine       power  \
# count   296.000000         296.000000  296.000000   296.000000  296.000000
# mean   2013.540541       57791.131757   18.401486  1641.679054  115.548953
# std       2.971910       35160.124277    4.118522   605.490334   58.643606
# min    2002.000000        1000.000000    7.810000   624.000000   35.000000
# 25%    2012.000000       34153.000000   15.175000  1199.000000   76.950000
# 50%    2014.000000       53000.000000   18.565000  1497.000000  100.300000
# 75%    2016.000000       70000.500000   21.157500  1992.000000  140.000000
# max    2019.000000      262000.000000   28.400000  5461.000000  500.000000
#
#             seats         price
# count  296.000000    296.000000
# mean     5.256757  13137.266892
# std      0.777842  14238.860963
# min      2.000000    733.000000
# 25%      5.000000   4666.000000
# 50%      5.000000   7939.500000
# 75%      5.000000  14859.750000
# max      8.000000  93813.000000

# %% [markdown]
# ## 2.3 Ajuste de la columna "name"
#
# En este punto se dividirá la información contenida en la columna "name" para obtener dos columnas independientes: "make" (marca) y "model" (modelo). Esta separación permitirá un análisis más detallado y segmentado de los vehículos.

# %%
df_cars.sample(5) 

    # Visualiza el dataframe para poder encontrar el dataframe
# Out:
#                                                name    location  year  \
# 224                                     Honda Civic  Abbottabad  2016
# 195                    Skoda Fabia 1.4 MPI Ambiente  Rawalpindi  2009
# 264                                      Mazda CX-5  Abbottabad  2018
# 106                                 Subaru Forester      Lahore  2017
# 285  Mercedes-Benz New C-Class C 220 CDI Avantgarde      Multan  2015
#
#      kilometers_driven fuel_type transmission owner_type  mileage  engine  \
# 224              64000    Diesel       Manual      First    22.90    1248
# 195              87459    Petrol       Manual      First    14.70    1390
# 264              31025    Diesel       Manual      First    28.40    1248
# 106              38053    Petrol       Manual      First    15.10    1196
# 285              77771    Diesel    Automatic      First    19.27    2143
#
#      power  seats  price
# 224   74.0      5   9066
# 195   85.0      5   3666
# 264   74.0      5   9533
# 106   73.0      5   5213
# 285  170.0      5  24853

# %%
df_cars["make"] = df_cars["name"].str.extract(r"(^\w+\-?\w+)")

    # Crea una columna nueva llamada "make", extrae el "name" hasta el primer espacio y lo añade a esta nueva columna

df_cars["model"] = df_cars["name"].str.replace(r"(^\w+\-?\w+)", "", regex=True)

    # Crea una columna nueva llamada "model", elimina el "name" hasta el primer espacio y añade el resto a esta nueva columna

df_cars.sample()

    # Visualiza el DataFrame para comprobar que se ha modificado
# Out:
#                               name location  year  kilometers_driven  \
# 273  Hyundai Verna 1.6 SX VTVT (O)   Multan  2012              54308
#
#     fuel_type transmission owner_type  mileage  engine  power  seats  price  \
# 273    Petrol       Manual      First     17.1    1591  121.3      5   5706
#
#         make                   model
# 273  Hyundai   Verna 1.6 SX VTVT (O)

# %%
make = df_cars.pop("make")
model= df_cars.pop ("model")
df_cars.insert(0, "make", make)
df_cars.insert(1, "model", model)

    # Reordena las columnas para que aparezcan en las 2 primeras posiciones --> Facilidad de visualización

# %%
df_cars.drop("name", axis = 1, inplace = True) 

    # Elimina la columna "name" porque ya no aporta valor

# %%
df_cars.sample() 

    # Visualiza el DataFrame para comrpobar que el cambio se haya guardado
# Out:
#               make              model location  year  kilometers_driven  \
# 115  Mercedes-Benz   B Class B200 CDI  Karachi  2014              53753
#
#     fuel_type transmission owner_type  mileage  engine  power  seats  price
# 115    Diesel    Automatic     Second     15.0    2143  107.3      5  22333

# %% [markdown]
# ## 2.4 Guardar DataFrame limpio

# %%
df_cars.to_csv("./data/carlistings_limpio.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 df_cars.to_csv("./data/carlistings_limpio.csv", index=False)
#
# File c:\Users\Tato\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File c:\Users\Tato\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\generic.py:3989, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3978 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3980 formatter = DataFrameFormatter(
#    3981     frame=df,
#    3982     header=header,
#    (...)   3986     decimal=decimal,
#    3987 )
# -> 3989 return DataFrameRenderer(formatter).to_csv(
#    3990     path_or_buf,
#    3991     lineterminator=lineterminator,
#    3992     sep=sep,
#    3993     encoding=encoding,
#    3994     errors=errors,
#    3995     compression=compression,
#    3996     quoting=quoting,
#    3997     columns=columns,
#    3998     index_label=index_label,
#    3999     mode=mode,
#    4000     chunksize=chunksize,
#    4001     quotechar=quotechar,
#    4002     date_format=date_format,
#    4003     doublequote=doublequote,
#    4004     escapechar=escapechar,
#    4005     storage_options=storage_options,
#    4006 )
#
# File c:\Users\Tato\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\formats\format.py:1014, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#     993     created_buffer = False
#     995 csv_formatter = CSVFormatter(
#     996     path_or_buf=path_or_buf,
#     997     lineterminator=lineterminator,
#    (...)   1012     formatter=self.fmt,
#    1013 )
# -> 1014 csv_formatter.save()
#    1016 if created_buffer:
#    1017     assert isinstance(path_or_buf, StringIO)
#
# File c:\Users\Tato\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\formats\csvs.py:251, in CSVFormatter.save(self)
#     247 """
#     248 Create the writer & save.
#     249 """
#     250 # apply compression and byte/text conversion
# --> 251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#     254     encoding=self.encoding,
#     255     errors=self.errors,
#     256     compression=self.compression,
#     257     storage_options=self.storage_options,
#     258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     self.writer = csvlib.writer(
#     261         handles.handle,
#     262         lineterminator=self.lineterminator,
#    (...)    267         quotechar=self.quotechar,
#     268     )
#     270     self._save()
#
# File c:\Users\Tato\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\common.py:749, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     747 # Only for write methods
#     748 if "r" not in mode and is_path:
# --> 749     check_parent_directory(str(handle))
#     751 if compression:
#     752     if compression != "zstd":
#     753         # compression libraries do not like an explicit text-mode
#
# File c:\Users\Tato\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\common.py:616, in check_parent_directory(path)
#     614 parent = Path(path).parent
#     615 if not parent.is_dir():
# --> 616     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: 'data'
